# %%
import pandas as pd  #importing pandas to create and work on dataframes
import numpy as np   #for creating numpy arrays
import seaborn as sns #for visualising the data

from sklearn import metrics  #metrics are used to evaluate the model
from sklearn.preprocessing import LabelEncoder   # labelencoder is used to convert the data type from object to categorical

import warnings 
from sklearn.metrics import classification_report,confusion_matrix,r2_score,mean_squared_error #various evaluation methods

warnings.filterwarnings("ignore")  # to ignore the warnings

# %%
df = pd.read_csv('adult-all.csv')  # reading the data as a dataframe using pandas

# %%
df #to have an overview of how the data looks
# Out:
#        39         State-gov   77516  Bachelors  13       Never-married  \
# 0      50  Self-emp-not-inc   83311  Bachelors  13  Married-civ-spouse
# 1      38           Private  215646    HS-grad   9            Divorced
# 2      53           Private  234721       11th   7  Married-civ-spouse
# 3      28           Private  338409  Bachelors  13  Married-civ-spouse
# 4      37           Private  284582    Masters  14  Married-civ-spouse
# ...    ..               ...     ...        ...  ..                 ...
# 48836  39           Private  215419  Bachelors  13            Divorced
# 48837  64                 ?  321403    HS-grad   9             Widowed
# 48838  38           Private  374983  Bachelors  13  Married-civ-spouse
# 48839  44           Private   83891  Bachelors  13            Divorced
# 48840  35      Self-emp-inc  182148  Bachelors  13  Married-civ-spouse
#
#             Adm-clerical   Not-in-family               White    Male  2174  0  \
# 0        Exec-managerial         Husband               White    Male     0  0
# 1      Handlers-cleaners   Not-in-family               White    Male     0  0
# 2      Handlers-cleaners         Husband               Black    Male     0  0
# 3         Prof-specialty            Wife               Black  Female     0  0
# 4        Exec-managerial            Wife               White  Female     0  0
# ...                  ...             ...                 ...     ...   ... ..
# 48836     Prof-specialty   Not-in-family               White  Female     0  0
# 48837                  ?  Other-relative               Black    Male     0  0
# 48838     Prof-specialty         Husband               White    Male     0  0
# 48839       Adm-clerical       Own-child  Asian-Pac-Islander    Male  5455  0
# 48840    Exec-managerial         Husband               White    Male     0  0
#
#        40  United-States  <=50K
# 0      13  United-States  <=50K
# 1      40  United-States  <=50K
# 2      40  United-States  <=50K
# 3      40           Cuba  <=50K
# 4      40  United-States  <=50K
# ...    ..            ...    ...
# 48836  36  United-States  <=50K
# 48837  40  United-States  <=50K
# 48838  50  United-States  <=50K
# 48839  40  United-States  <=50K
# 48840  60  United-States   >50K
#
# [48841 rows x 15 columns]

# %%
df = df.drop('77516',axis = 1)  #dropping unnecessary columns

# %%
df = df.drop('13',axis = 1)

# %%
df = df.drop('39',axis = 1)

# %%
df = df.drop('2174',axis = 1)

# %%
df = df.drop('0',axis = 1)

# %%
df = df.drop('40',axis = 1)

# %%
#renaming the cols with appropriate nomencleature

df = df.rename(columns={"United-States": "country", "White": "race","Not-in-family": "family status","State-gov": "job category","Bachelors": "education","Never-married": "marital status","Male": "gender","<=50K": "salary"})

# %%
df.head(50)  #to overview the dataframe
# Out:
#         job category     education         marital status       Adm-clerical  \
# 0   Self-emp-not-inc     Bachelors     Married-civ-spouse    Exec-managerial
# 1            Private       HS-grad               Divorced  Handlers-cleaners
# 2            Private          11th     Married-civ-spouse  Handlers-cleaners
# 3            Private     Bachelors     Married-civ-spouse     Prof-specialty
# 4            Private       Masters     Married-civ-spouse    Exec-managerial
# 5            Private           9th  Married-spouse-absent      Other-service
# 6   Self-emp-not-inc       HS-grad     Married-civ-spouse    Exec-managerial
# 7            Private       Masters          Never-married     Prof-specialty
# 8            Private     Bachelors     Married-civ-spouse    Exec-managerial
# 9            Private  Some-college     Married-civ-spouse    Exec-managerial
# 10         State-gov     Bachelors     Married-civ-spouse     Prof-specialty
# 11           Private     Bachelors          Never-married       Adm-clerical
# 12           Private    Assoc-acdm          Never-married              Sales
# 13           Private     Assoc-voc     Married-civ-spouse       Craft-repair
# 14           Private       7th-8th     Married-civ-spouse   Transport-moving
# 15  Self-emp-not-inc       HS-grad          Never-married    Farming-fishing
# 16           Private       HS-grad          Never-married  Machine-op-inspct
# 17           Private          11th     Married-civ-spouse              Sales
# 18  Self-emp-not-inc       Masters               Divorced    Exec-managerial
# 19           Private     Doctorate     Married-civ-spouse     Prof-specialty
# 20           Private       HS-grad              Separated      Other-service
# 21       Federal-gov           9th     Married-civ-spouse    Farming-fishing
# 22           Private          11th     Married-civ-spouse   Transport-moving
# 23           Private       HS-grad               Divorced       Tech-support
# 24         Local-gov     Bachelors     Married-civ-spouse       Tech-support
# 25           Private       HS-grad          Never-married       Craft-repair
# 26                 ?  Some-college     Married-civ-spouse                  ?
# 27           Private       HS-grad               Divorced    Exec-managerial
# 28           Private       HS-grad     Married-civ-spouse       Craft-repair
# 29         Local-gov    Assoc-acdm          Never-married    Protective-serv
# 30           Private  Some-college          Never-married              Sales
# 31           Private     Bachelors               Divorced    Exec-managerial
# 32       Federal-gov  Some-college     Married-civ-spouse       Adm-clerical
# 33         State-gov  Some-college     Married-civ-spouse      Other-service
# 34           Private          11th          Never-married  Machine-op-inspct
# 35           Private  Some-college          Never-married  Machine-op-inspct
# 36           Private       HS-grad      Married-AF-spouse       Adm-clerical
# 37           Private  Some-college     Married-civ-spouse              Sales
# 38  Self-emp-not-inc    Assoc-acdm     Married-civ-spouse     Prof-specialty
# 39           Private           9th     Married-civ-spouse  Machine-op-inspct
# 40  Self-emp-not-inc     Bachelors     Married-civ-spouse     Prof-specialty
# 41           Private     Bachelors     Married-civ-spouse       Tech-support
# 42           Private       HS-grad              Separated       Adm-clerical
# 43           Private       HS-grad          Never-married  Handlers-cleaners
# 44       Federal-gov     Bachelors     Married-civ-spouse     Prof-specialty
# 45           Private       HS-grad     Married-civ-spouse  Machine-op-inspct
# 46           Private       Masters               Divorced    Exec-managerial
# 47         State-gov     Assoc-voc     Married-civ-spouse       Craft-repair
# 48           Private     Assoc-voc          Never-married     Prof-specialty
# 49           Private  Some-college     Married-civ-spouse    Exec-managerial
#
#     family status                race  gender        country salary
# 0         Husband               White    Male  United-States  <=50K
# 1   Not-in-family               White    Male  United-States  <=50K
# 2         Husband               Black    Male  United-States  <=50K
# 3            Wife               Black  Female           Cuba  <=50K
# 4            Wife               White  Female  United-States  <=50K
# 5   Not-in-family               Black  Female        Jamaica  <=50K
# 6         Husband               White    Male  United-States   >50K
# 7   Not-in-family               White  Female  United-States   >50K
# 8         Husband               White    Male  United-States   >50K
# 9         Husband               Black    Male  United-States   >50K
# 10        Husband  Asian-Pac-Islander    Male          India   >50K
# 11      Own-child               White  Female  United-States  <=50K
# 12  Not-in-family               Black    Male  United-States  <=50K
# 13        Husband  Asian-Pac-Islander    Male              ?   >50K
# 14        Husband  Amer-Indian-Eskimo    Male         Mexico  <=50K
# 15      Own-child               White    Male  United-States  <=50K
# 16      Unmarried               White    Male  United-States  <=50K
# 17        Husband               White    Male  United-States  <=50K
# 18      Unmarried               White  Female  United-States   >50K
# 19        Husband               White    Male  United-States   >50K
# 20      Unmarried               Black  Female  United-States  <=50K
# 21        Husband               Black    Male  United-States  <=50K
# 22        Husband               White    Male  United-States  <=50K
# 23      Unmarried               White  Female  United-States  <=50K
# 24        Husband               White    Male  United-States   >50K
# 25      Own-child               White    Male  United-States  <=50K
# 26        Husband  Asian-Pac-Islander    Male          South   >50K
# 27  Not-in-family               White    Male  United-States  <=50K
# 28        Husband               White    Male  United-States  <=50K
# 29  Not-in-family               White    Male  United-States  <=50K
# 30      Own-child               Black    Male  United-States  <=50K
# 31      Own-child               White    Male  United-States  <=50K
# 32      Own-child               White    Male  United-States  <=50K
# 33        Husband               Black    Male  United-States  <=50K
# 34      Unmarried               White    Male    Puerto-Rico  <=50K
# 35      Own-child               White    Male  United-States  <=50K
# 36           Wife               White  Female  United-States  <=50K
# 37        Husband               White    Male              ?   >50K
# 38        Husband               White    Male  United-States  <=50K
# 39        Husband               White    Male  United-States  <=50K
# 40        Husband               White    Male  United-States  <=50K
# 41        Husband               White    Male  United-States  <=50K
# 42      Unmarried               White  Female  United-States  <=50K
# 43  Not-in-family               White    Male  United-States  <=50K
# 44        Husband               Black    Male  United-States   >50K
# 45        Husband               White    Male  United-States  <=50K
# 46      Unmarried               White  Female  United-States  <=50K
# 47        Husband               White    Male  United-States  <=50K
# 48  Not-in-family               White    Male  United-States  <=50K
# 49           Wife               Other  Female  United-States  <=50K

# %%
df = df.replace({'?': np.nan}).dropna()  #dropping the rows with the question mark in them
df.shape # to know the shape of the data
# Out:
# (45221, 9)

# %%
df.head(50) #data without any question mark
# Out:
#         job category     education         marital status       Adm-clerical  \
# 0   Self-emp-not-inc     Bachelors     Married-civ-spouse    Exec-managerial
# 1            Private       HS-grad               Divorced  Handlers-cleaners
# 2            Private          11th     Married-civ-spouse  Handlers-cleaners
# 3            Private     Bachelors     Married-civ-spouse     Prof-specialty
# 4            Private       Masters     Married-civ-spouse    Exec-managerial
# 5            Private           9th  Married-spouse-absent      Other-service
# 6   Self-emp-not-inc       HS-grad     Married-civ-spouse    Exec-managerial
# 7            Private       Masters          Never-married     Prof-specialty
# 8            Private     Bachelors     Married-civ-spouse    Exec-managerial
# 9            Private  Some-college     Married-civ-spouse    Exec-managerial
# 10         State-gov     Bachelors     Married-civ-spouse     Prof-specialty
# 11           Private     Bachelors          Never-married       Adm-clerical
# 12           Private    Assoc-acdm          Never-married              Sales
# 14           Private       7th-8th     Married-civ-spouse   Transport-moving
# 15  Self-emp-not-inc       HS-grad          Never-married    Farming-fishing
# 16           Private       HS-grad          Never-married  Machine-op-inspct
# 17           Private          11th     Married-civ-spouse              Sales
# 18  Self-emp-not-inc       Masters               Divorced    Exec-managerial
# 19           Private     Doctorate     Married-civ-spouse     Prof-specialty
# 20           Private       HS-grad              Separated      Other-service
# 21       Federal-gov           9th     Married-civ-spouse    Farming-fishing
# 22           Private          11th     Married-civ-spouse   Transport-moving
# 23           Private       HS-grad               Divorced       Tech-support
# 24         Local-gov     Bachelors     Married-civ-spouse       Tech-support
# 25           Private       HS-grad          Never-married       Craft-repair
# 27           Private       HS-grad               Divorced    Exec-managerial
# 28           Private       HS-grad     Married-civ-spouse       Craft-repair
# 29         Local-gov    Assoc-acdm          Never-married    Protective-serv
# 45        Husband               White    Male  United-States  <=50K
# 46      Unmarried               White  Female  United-States  <=50K
# 47        Husband               White    Male  United-States  <=50K
# 48  Not-in-family               White    Male  United-States  <=50K
# 49           Wife               Other  Female  United-States  <=50K
# 51           Wife               White  Female       Honduras   >50K
# 52  Not-in-family               White    Male  United-States   >50K
# 53  Not-in-family               White    Male  United-States  <=50K

# %%
df.isna().sum() #to check the count of nan values in each column
# Out:
# job category      0
# education         0
# marital status    0
# Adm-clerical      0
# family status     0
# race              0
# gender            0
# country           0
# salary            0
# dtype: int64

# %%
df.info() #to check the datatype of cols
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45221 entries, 0 to 48840
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   job category    45221 non-null  object
#  1   education       45221 non-null  object
#  2   marital status  45221 non-null  object
#  3   Adm-clerical    45221 non-null  object
#  4   family status   45221 non-null  object
#  5   race            45221 non-null  object
#  6   gender          45221 non-null  object
#  7   country         45221 non-null  object
#  8   salary          45221 non-null  object
# dtypes: object(9)
# memory usage: 3.5+ MB

# %%
le = LabelEncoder() #to convert the data type from object to category

# %%
df["job category"] = le.fit_transform(df["job category"])
df["education"] = le.fit_transform(df["education"])
df["Adm-clerical"] = le.fit_transform(df["Adm-clerical"])
df["family status"] = le.fit_transform(df["family status"])
df["race"] = le.fit_transform(df["race"])
df["marital status"] = le.fit_transform(df["marital status"])
df["gender"] = le.fit_transform(df["gender"])
df["country"] = le.fit_transform(df["country"])
df["salary"] = le.fit_transform(df["salary"])

# %%
df["job category"] = df["job category"].astype("category")

# %%
df["education"] = df["education"].astype("category")

# %%
df["Adm-clerical"] = df["Adm-clerical"].astype("category")

# %%
df["family status"] = df["family status"].astype("category")

# %%
df["race"] = df["race"].astype("category")

# %%
df["marital status"] = df["marital status"].astype("category")

# %%
df["gender"] = df["gender"].astype("category")

# %%
df["country"] = df["country"].astype("category")

# %%
df["salary"] = df["salary"].astype("category")

# %%
df.info() #to check the conversion of data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45221 entries, 0 to 48840
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   job category    45221 non-null  category
#  1   education       45221 non-null  category
#  2   marital status  45221 non-null  category
#  3   Adm-clerical    45221 non-null  category
#  4   family status   45221 non-null  category
#  5   race            45221 non-null  category
#  6   gender          45221 non-null  category
#  7   country         45221 non-null  category
#  8   salary          45221 non-null  category
# dtypes: category(9)
# memory usage: 754.8 KB

# %%
df_feat = df.drop('salary',axis = 1) #for the feature matrix

# %%
from sklearn.model_selection import train_test_split #to split the data into test and train data

# %%
X = df_feat 
y = df['salary'] #target variable
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101) #taking 70% as train data

# %%
from sklearn.neighbors import KNeighborsClassifier #importing algorithm

# %%
knn = KNeighborsClassifier(n_neighbors=20) #randomly initialized k-value of 20

# %%
knn.fit(X_train,y_train) #fitting the algorithm with training data
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
y_pred = knn.predict(X_test)  #predicting how the algorithm works with test data

# %%
mse = mean_squared_error(y_pred,y_test) #testing the error between predicted data and the actual data
mse
# Out:
# 0.18279649148669566

# %%
print(confusion_matrix(y_pred,y_test)) #making a confusion matrix of the predicted data and actual data
# Out:
# [[9413 1757]
#  [ 723 1674]]

# %%
print(classification_report(y_pred,y_test)) #making a classification report of the prediction
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.84      0.88     11170
#            1       0.49      0.70      0.57      2397
#
#     accuracy                           0.82     13567
#    macro avg       0.71      0.77      0.73     13567
# weighted avg       0.85      0.82      0.83     13567

# %%
#accuracy of our model is found to be 82 %
